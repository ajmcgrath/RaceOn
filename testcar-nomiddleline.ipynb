# %%
from picamera.array import PiYUVArray, PiRGBArray
from picamera import PiCamera

from scipy.signal import find_peaks, butter, filtfilt

import time
import matplotlib.pyplot as plt
import skimage as ski
import numpy as np

# Camera resolution
res = (640, 480)

CAMERA_CENTER = res[0] // 2
CAMERA_CENTER -= 80
       
from pwm import PWM

# %% [markdown]
# ## Setup servo and motor PWM signal to control the steering angle and the speed.
#
# The values specified period and duty cycle ar in nanoseconds.
#
# Servo and motor controlled follow the following protocol:
#   1. Control signal is read 50 times per second by each device (servo and speed controller). Thus period is 20 ms => 20000000 ns
#   2. To send the minimum value (full left for servo and break for motor) the duty cycle should be 1 ms => 1000000 ns
#   3. Maximum value corresponds to a duty cycle of 2 ms => 2000000 ns
#
# However, these devices are not perfect and you can set a duty cycle outside this range and still get a response. I would recoment to play with it and find are the limits in your case. Pay attention that servo is limited by the mechanical construction how much it can turn the wheels. Do not set these limits to a value which servo cannot execute as it will try to do that and eventually burn.

# %%
# Enable servo
#SERVO_MIDDLE = 1600000 #right
SERVO_MIDDLE = 2070000 #middle
#SERVO_MIDDLE = 2500000 #left


servo = PWM(1)
servo.period = 20000000
servo.duty_cycle = SERVO_MIDDLE
servo.enable = True

# %%
# Enable servo
#MOTOR_BRAKE = 1000000
MOTOR_BRAKE = 200000

motor = PWM(0)
motor.period = 20000000
motor.duty_cycle = MOTOR_BRAKE
motor.enable = True

# %%
motor.duty_cycle = MOTOR_BRAKE

# %% [markdown]
# ## The self driving code
#
# Quick explanation on how this algorithm works:
#   1. Initialize the camera, use a frame rate of 10 to 20 fps
#   2. Get the coefficients of the butterworth filter of order 3 and cut-off frequency of 0.1 (change cut of frequency if the peak functions is not working)
#   3. For each frame captured from the camera:
#     1. Get the blak and white part of the image
#     2. Select line 195 to use for lane detection (this number depends on your camera angle)
#     3. Filter the line and find the peaks that are greater than 160. White parts of the image have higher values than the black. The threshold of 160 depends on the ambient light, lower if the room is darker
#     4. Find the peaks left and right of the camera center, these peaks should corresponds to the white lines delimiting the track,
#     5. Compute the center point between these lines. This is where we want our car
#     6. Compute the error by substracting the center point from camera middle and multiply by 5000. 5000 is our P gain.
#     7. Adjust the duty cycle of the servo such that the

# %%
# Run a track detection algorithm on a single horizontal line.
# Uses YUV420 image format as the Y component corresponds to image intensity (gray image)
# and thus there is no need to convert from RGB to BW

RUN_TIMER = 60 #seconds
history=[]

camera = PiCamera()
        
# Check the link below for the combinations between mode and resolution
# https://picamera.readthedocs.io/en/release-1.13/fov.html#sensor-modes
camera.sensor_mode = 7
camera.resolution = res
camera.framerate = 10

# Initialize the buffer and start capturing
rawCapture = PiYUVArray(camera, size=res)
stream = camera.capture_continuous(rawCapture, format="yuv", use_video_port=True)

# Measure the time needed to process 300 images to estimate the FPS
t = time.time()

# To filter the noise in the image we use a 3rd order Butterworth filter

# Wn = 0.02, the cut-off frequency, acceptable values are from 0 to 1
b, a = butter(3, 0.1)

line_pos    = CAMERA_CENTER
first_frame = True
track_width = 530 # based on what was returned in "line_left and line_right" condition

# start car
FAST_STRAIGHT = MOTOR_BRAKE + 675000 #1200000
SLOW_TURN = MOTOR_BRAKE + 575000 #int(0.936170213 * FAST_STRAIGHT)  #MOTOR_BRAKE + 900000 #1150000

motor.duty_cycle = FAST_STRAIGHT #SLOW_TURN #MOTOR_BRAKE + 1050000 #875000  #350000 #120000


#left_count = 0
#straight_count = 0
count = 0    #left  = - right = +
COUNT_VAL = 3 #3 #6

for f in stream:
    if first_frame:
        first_frame = False
        # Reset the buffer for the next image
        rawCapture.truncate(0)
        continue
    
    # Stop after RUN_TIMER seconds
    if (time.time() - t) > RUN_TIMER:
        break
        
    # Get the intensity component of the image (a trick to get black and white images)
    I = f.array[:, :, 0]
    I = I[120:300,:] #120
    
    # Reset the buffer for the next image
    rawCapture.truncate(0)
    
    # Select a horizontal line in the middle of the image
#     L = I[195, :]
    L = I[50, :] #75 #40
    
    # Smooth the transitions so we can detect the peaks 
    Lf = filtfilt(b, a, L)
    history.append(Lf)

    # Find peaks which are higher than 0.5
    p = find_peaks(Lf, height=160)
    
    peaks = p[0]
    
    line_left   = None
    line_right  = None 
    
    peaks_left  = peaks[peaks < CAMERA_CENTER]
    peaks_right = peaks[peaks > CAMERA_CENTER]

    if peaks_left.size:
        line_left = peaks_left.max()

    if peaks_right.size:
        line_right = peaks_right.min()
        
    if line_left and line_right:
        
        line_pos    = (line_left + line_right ) // 2
#         line_pos    -= 40 # calibration issue
        track_width = line_right - line_left
        DUTY_CYCLE = SERVO_MIDDLE - 1000 * (CAMERA_CENTER - line_pos)
        print('left and right')
        if count <= -1 :
            count += 1
            if count != 0 :
                DUTY_CYCLE = int((2500000 + ((2500000 - SERVO_MIDDLE) / COUNT_VAL)) - ((2500000 - SERVO_MIDDLE) / abs(count))) 
            else :
                motor.duty_cycle = FAST_STRAIGHT
                DUTY_CYCLE = SERVO_MIDDLE
        elif count >= 1 :
            count -= 1
            if count != 0 :
                DUTY_CYCLE = int((1600000 - ((SERVO_MIDDLE - 1600000) / COUNT_VAL)) + (( SERVO_MIDDLE - 1600000) / abs(count)))   
            else :
                motor.duty_cycle = FAST_STRAIGHT
                DUTY_CYCLE = SERVO_MIDDLE
        
        #straight_count += 1
        #if straight_count % 5:
        #    
#         DUTY_CYCLE = SERVO_MIDDLE - 1000 * (CAMERA_CENTER - line_pos)
        #else :
        #    DUTY_CYCLE = SERVO_MIDDLE

#         print(line_pos, line_left, line_right) # 362, 99, 625
        
    elif line_left and not line_right:
        if count < COUNT_VAL :#3
            count += 1
        
        motor.duty_cycle = SLOW_TURN
        line_pos    = line_left + int(track_width / 2)
        print('left and not right')
#         DUTY_CYCLE = SERVO_MIDDLE - 1000 * (CAMERA_CENTER - line_pos)
        if(count!=0) :
            DUTY_CYCLE = int(SERVO_MIDDLE - (((SERVO_MIDDLE - 1600000) / COUNT_VAL) * abs(count))) #1650000 
        else :
            DUTY_CYCLE = int(SERVO_MIDDLE - (((SERVO_MIDDLE - 1600000) / COUNT_VAL) * abs(count+1)))
        
    elif not line_left and line_right:
        if count > -(COUNT_VAL + 2)  :             #3
            count -= 1
        motor.duty_cycle = SLOW_TURN
        line_pos    = line_right - int(track_width / 2)
        print('right and not left')
        if(count!=0) :
            DUTY_CYCLE = int(SERVO_MIDDLE + (((2500000 - SERVO_MIDDLE) / (COUNT_VAL + 2)) * abs(count))) #2450000 
        else :
            DUTY_CYCLE = int(SERVO_MIDDLE + (((2500000 - SERVO_MIDDLE) / (COUNT_VAL + 2)) * abs(count-1)))
        
    else:
#         DUTY_CYCLE = SERVO_MIDDLE
#         motor.duty_cycle = FAST_STRAIGHT
        print("no line")
        count = 0
        continue
        
        
    #print(line_pos, peaks)

#     DUTY_CYCLE = SERVO_MIDDLE - 1000 * (CAMERA_CENTER - line_pos)# + 5000 * (CAMERA_CENTER - line_pos)
    #print("mid:", SERVO_MIDDLE)
    print("dif:", (CAMERA_CENTER - line_pos))
#     print("cyc:",DUTY_CYCLE)
    
    if DUTY_CYCLE > 2500000:
        DUTY_CYCLE = 2500000
    if DUTY_CYCLE < 1600000:
        DUTY_CYCLE = 1600000
        
       
    servo.duty_cycle =  DUTY_CYCLE
    print(count)
        
#Initialize lines position
#Check which lines are closer them in the next frame

        
        #print(line_pos)
motor.duty_cycle = MOTOR_BRAKE    
    

# Release resources
stream.close()
rawCapture.close()
camera.close()
# Out:
# left and not right
# dif: -81
# 1
# left and not right
# dif: -81
# 2
# left and not right
# dif: -81
# 3
# left and not right
# dif: -81
# 3
# left and not right
# dif: -81
# 3
# left and not right
# dif: -81
# 3
# left and not right
# dif: -80
# 3
# left and not right
# dif: -80
# 3
# left and not right
# dif: -80
# 3
# left and not right
# dif: -80
# 3
# left and not right
# dif: -80
# 3
# left and not right
# dif: -80
# 3
# left and not right
# dif: -80
# 3
# left and not right
# dif: -80
# 3
# left and not right
# dif: -80
# 3
# left and not right
# dif: -80
# 3
# left and not right
# dif: -80
# 3
# left and not right
# dif: -81
# 3
# left and not right
# dif: -80
# 3
# left and not right
# dif: -80
# 3
# left and not right
# dif: -80
# 3
# left and not right
# dif: -80
# 3
# left and not right
# dif: -80
# 3
# left and not right
# dif: -80
# 3
# left and not right
# dif: -80
# 3
# left and not right
# dif: -80
# 3
# left and not right
# dif: -80
# 3
# left and not right
# dif: -80
# 3
# left and not right
# dif: -80
# 3
# left and not right
# dif: -80
# 3
# left and not right
# dif: -80
# 3
# left and not right
# dif: -80
# 3
# left and not right
# dif: -80
# 3
# left and not right
# dif: -80
# 3
# left and not right
# dif: -80
# 3
# left and not right
# dif: -80
# 3
# left and not right
# dif: -80
# 3
# left and not right
# dif: -80
# 3
# left and not right
# dif: -80
# 3
# left and not right
# dif: -80
# 3
# left and not right
# dif: -80
# 3
# left and not right
# dif: -80
# 3
# left and not right
# dif: -80
# 3
# left and not right
# dif: -80
# 3
# left and not right
# dif: -80
# 3
# left and not right
# dif: -80
# 3
# left and not right
# dif: -80
# 3
# left and not right
# dif: -80
# 3
# left and not right
# dif: -80
# 3
# left and not right
# dif: -80
# 3
# left and not right
# dif: -80
# 3
# left and not right
# dif: -80
# 3
# left and not right
# dif: -80
# 3
# left and not right
# dif: -80
# 3
# left and not right
# dif: -80
# 3
# left and not right
# dif: -80
# 3
# left and not right
# dif: -80
# 3
# left and not right
# dif: -80
# 3
# left and not right
# dif: -80
# 3
# left and not right
# dif: -80
# 3
# left and not right
# dif: -80
# 3
# left and not right
# dif: -80
# 3
# left and not right
# dif: -80
# 3
# left and not right
# dif: -80
# 3
# left and not right
# dif: -80
# 3
# left and not right
# dif: -80
# 3
# left and not right
# dif: -80
# 3
# left and not right
# dif: -80
# 3
# left and not right
# dif: -80
# 3
# left and not right
# dif: -80
# 3
# left and not right
# dif: -76
# 3
# left and not right
# dif: -77
# 3
# left and not right
# dif: -74
# 3
# left and right
# dif: -102
# 2
# left and right
# dif: -101
# 1
# left and right
# dif: -99
# 0
# left and right
# dif: -94
# 0
# left and right
# dif: -89
# 0
# left and right
# dif: -88
# 0
# left and right
# dif: -84
# 0
# left and right
# dif: -83
# 0
# left and right
# dif: -85
# 0
# left and right
# dif: -81
# 0
# left and right
# dif: -79
# 0
# left and right
# dif: -81
# 0
# left and right
# dif: -74
# 0
# left and right
# dif: -76
# 0
# left and right
# dif: -75
# 0
# left and right
# dif: -70
# 0
# left and right
# dif: -70
# 0
# left and right
# dif: -72
# 0
# left and right
# dif: -68
# 0
# left and right
# dif: -68
# 0
# left and right
# dif: -67
# 0
# left and right
# dif: -66
# 0
# left and right
# dif: -67
# 0
# left and right
# dif: -64
# 0
# left and right
# dif: -65
# 0
# left and right
# dif: -63
# 0
# right and not left
# dif: -55
# -1
# right and not left
# dif: -61
# -2
# right and not left
# dif: -54
# -3
# right and not left
# dif: -61
# -4
# right and not left
# dif: -69
# -5
# right and not left
# dif: -80
# -5
# right and not left
# dif: -91
# -5
# right and not left
# dif: -104
# -5
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# right and not left
# dif: -113
# -1
# right and not left
# dif: -114
# -2
# right and not left
# dif: -107
# -3
# right and not left
# dif: -105
# -4
# right and not left
# dif: -103
# -5
# right and not left
# dif: -101
# -5
# left and right
# dif: -78
# -4
# left and right
# dif: -77
# -3
# left and right
# dif: -83
# -2
# left and right
# dif: -87
# -1
# left and right
# dif: -92
# 0
# left and right
# dif: -95
# 0
# left and right
# dif: -99
# 0
# left and right
# dif: -99
# 0
# left and right
# dif: -100
# 0
# left and right
# dif: -101
# 0
# left and right
# dif: -101
# 0
# left and right
# dif: -99
# 0
# left and right
# dif: -103
# 0
# left and right
# dif: -104
# 0
# left and not right
# dif: -108
# 1
# left and not right
# dif: -115
# 2
# left and not right
# dif: -113
# 3
# left and not right
# dif: -118
# 3
# left and not right
# dif: -114
# 3
# left and not right
# dif: -113
# 3
# left and not right
# dif: -109
# 3
# left and not right
# dif: -108
# 3
# left and not right
# dif: -106
# 3
# left and not right
# dif: -106
# 3
# left and not right
# dif: -104
# 3
# left and not right
# dif: -104
# 3
# left and not right
# dif: -102
# 3
# left and not right
# dif: -101
# 3
# left and not right
# dif: -99
# 3
# left and not right
# dif: -97
# 3
# left and right
# dif: -101
# 2
# left and right
# dif: -101
# 1
# left and right
# dif: -95
# 0
# left and right
# dif: -90
# 0
# left and right
# dif: -85
# 0
# left and right
# dif: -90
# 0
# left and right
# dif: -93
# 0
# left and right
# dif: -97
# 0
# left and right
# dif: -103
# 0
# left and right
# dif: -105
# 0
# left and right
# dif: -109
# 0
# left and not right
# dif: -115
# 1
# left and not right
# dif: -120
# 2
# left and not right
# dif: -123
# 3
# left and not right
# dif: -125
# 3
# left and not right
# dif: -119
# 3
# left and not right
# dif: -111
# 3
# left and right
# dif: -106
# 2
# left and right
# dif: -98
# 1
# left and right
# dif: -88
# 0
# left and right
# dif: -85
# 0
# left and right
# dif: -76
# 0
# left and right
# dif: -74
# 0
# left and right
# dif: -68
# 0
# left and right
# dif: -72
# 0
# left and right
# dif: -69
# 0
# left and right
# dif: -74
# 0
# left and right
# dif: -80
# 0
# left and not right
# dif: -81
# 1
# left and not right
# dif: -88
# 2
# left and not right
# dif: -95
# 3
# left and not right
# dif: -90
# 3
# left and not right
# dif: -89
# 3
# left and not right
# dif: -96
# 3
# left and not right
# dif: -88
# 3
# left and not right
# dif: -91
# 3
# left and not right
# dif: -91
# 3
# left and not right
# dif: -93
# 3
# left and not right
# dif: -93
# 3
# left and not right
# dif: -91
# 3
# left and right
# dif: -103
# 2
# left and right
# dif: -99
# 1
# left and right
# dif: -90
# 0
# right and not left
# dif: -83
# -1
# right and not left
# dif: -77
# -2
# right and not left
# dif: -79
# -3
# right and not left
# dif: -77
# -4
# right and not left
# dif: -85
# -5
# right and not left
# dif: -90
# -5
# right and not left
# dif: -98
# -5
# right and not left
# dif: -105
# -5
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# left and not right
# dif: -53
# 1
# left and not right
# dif: -64
# 2
# left and not right
# dif: -75
# 3
# left and not right
# dif: -77
# 3
# left and not right
# dif: -74
# 3
# no line
# no line
# no line
# right and not left
# dif: -106
# -1
# right and not left
# dif: -101
# -2
# right and not left
# dif: -90
# -3
# right and not left
# dif: -74
# -4
# right and not left
# dif: -56
# -5
# right and not left
# dif: -33
# -5
# right and not left
# dif: -6
# -5
# right and not left
# dif: 10
# -5
# right and not left
# dif: 15
# -5
# right and not left
# dif: 24
# -5
# right and not left
# dif: 28
# -5
# right and not left
# dif: 22
# -5
# right and not left
# dif: 19
# -5
# right and not left
# dif: 11
# -5
# right and not left
# dif: -1
# -5
# right and not left
# dif: -6
# -5
# right and not left
# dif: -20
# -5
# right and not left
# dif: -30
# -5
# right and not left
# dif: -46
# -5
# right and not left
# dif: -57
# -5
# right and not left
# dif: -66
# -5
# right and not left
# dif: -74
# -5
# right and not left
# dif: -82
# -5
# right and not left
# dif: -94
# -5
# right and not left
# dif: -95
# -5
# right and not left
# dif: -106
# -5
# right and not left
# dif: -106
# -5
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# left and not right
# dif: -60
# 1
# left and not right
# dif: -71
# 2
# left and not right
# dif: -80
# 3
# left and not right
# dif: -84
# 3
# left and not right
# dif: -76
# 3
# left and not right
# dif: -65
# 3
# no line
# no line
# no line
# no line
# no line
# right and not left
# dif: -106
# -1
# right and not left
# dif: -101
# -2
# right and not left
# dif: -95
# -3
# right and not left
# dif: -71
# -4
# right and not left
# dif: -49
# -5
# right and not left
# dif: -17
# -5
# right and not left
# dif: 26
# -5
# right and not left
# dif: 41
# -5
# right and not left
# dif: 90
# -5
# right and not left
# dif: 111
# -5
# right and not left
# dif: 122
# -5
# right and not left
# dif: 135
# -5
# right and not left
# dif: 136
# -5
# right and not left
# dif: 137
# -5
# right and not left
# dif: 127
# -5
# right and not left
# dif: 123
# -5
# right and not left
# dif: 113
# -5
# right and not left
# dif: 97
# -5
# right and not left
# dif: 83
# -5
# right and not left
# dif: 65
# -5
# left and right
# dif: -2
# -4
# left and right
# dif: -14
# -3
# left and right
# dif: -27
# -2
# left and right
# dif: -41
# -1
# left and right
# dif: -55
# 0
# left and right
# dif: -65
# 0
# left and right
# dif: -71
# 0
# left and right
# dif: -69
# 0
# left and right
# dif: -71
# 0
# left and right
# dif: -78
# 0
# left and right
# dif: -76
# 0
# left and right
# dif: -82
# 0
# left and right
# dif: -82
# 0
# left and right
# dif: -85
# 0
# left and right
# dif: -86
# 0
# left and right
# dif: -88
# 0
# left and right
# dif: -91
# 0
# left and right
# dif: -92
# 0
# left and right
# dif: -97
# 0
# left and right
# dif: -98
# 0
# left and right
# dif: -104
# 0
# left and right
# dif: -106
# 0
# left and not right
# dif: -107
# 1
# left and not right
# dif: -110
# 2
# left and right
# dif: -107
# 1
# left and right
# dif: -105
# 0
# left and right
# dif: -93
# 0
# left and right
# dif: -88
# 0
# left and right
# dif: -83
# 0
# left and right
# dif: -78
# 0
# left and right
# dif: -80
# 0
# left and right
# dif: -83
# 0
# left and right
# dif: -78
# 0
# left and right
# dif: -80
# 0
# left and right
# dif: -77
# 0
# left and right
# dif: -80
# 0
# left and right
# dif: -75
# 0
# left and right
# dif: -73
# 0
# left and right
# dif: -70
# 0
# left and right
# dif: -69
# 0
# right and not left
# dif: -68
# -1
# right and not left
# dif: -62
# -2
# right and not left
# dif: -73
# -3
# right and not left
# dif: -69
# -4
# right and not left
# dif: -72
# -5
# right and not left
# dif: -84
# -5
# right and not left
# dif: -93
# -5
# right and not left
# dif: -100
# -5
# right and not left
# dif: -108
# -5
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# left and not right
# dif: -50
# 1
# left and not right
# dif: -57
# 2
# left and not right
# dif: -65
# 3
# left and not right
# dif: -67
# 3
# left and not right
# dif: -58
# 3
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# right and not left
# dif: -109
# -1
# right and not left
# dif: -108
# -2
# right and not left
# dif: -108
# -3
# right and not left
# dif: -102
# -4
# right and not left
# dif: -93
# -5
# right and not left
# dif: -80
# -5
# right and not left
# dif: -66
# -5
# right and not left
# dif: -48
# -5
# right and not left
# dif: -19
# -5
# right and not left
# dif: 2
# -5
# right and not left
# dif: 46
# -5
# right and not left
# dif: 117
# -5
# right and not left
# dif: 162
# -5
# right and not left
# dif: 186
# -5
# right and not left
# dif: 207
# -5
# right and not left
# dif: 215
# -5
# right and not left
# dif: 217
# -5
# right and not left
# dif: 212
# -5
# right and not left
# dif: 207
# -5
# right and not left
# dif: 199
# -5
# right and not left
# dif: 192
# -5
# right and not left
# dif: 177
# -5
# right and not left
# dif: 164
# -5
# right and not left
# dif: 146
# -5
# right and not left
# dif: 126
# -5
# right and not left
# dif: 111
# -5
# right and not left
# dif: 90
# -5
# left and right
# dif: 6
# -4
# left and right
# dif: -3
# -3
# left and right
# dif: -13
# -2
# left and right
# dif: -22
# -1
# left and right
# dif: -35
# 0
# left and right
# dif: -42
# 0
# left and right
# dif: -50
# 0
# left and right
# dif: -55
# 0
# left and right
# dif: -56
# 0
# left and right
# dif: -57
# 0
# left and right
# dif: -60
# 0
# left and right
# dif: -59
# 0
# left and right
# dif: -62
# 0
# left and right
# dif: -61
# 0
# left and right
# dif: -63
# 0
# left and right
# dif: -64
# 0
# left and right
# dif: -66
# 0
# left and right
# dif: -66
# 0
# left and right
# dif: -70
# 0
# left and right
# dif: -70
# 0
# left and right
# dif: -70
# 0
# left and right
# dif: -70
# 0
# left and right
# dif: -73
# 0
# left and right
# dif: -73
# 0
# left and right
# dif: -75
# 0
# left and right
# dif: -75
# 0
# left and right
# dif: -77
# 0
# left and right
# dif: -74
# 0
# left and right
# dif: -78
# 0
# left and right
# dif: -77
# 0
# right and not left
# dif: -75
# -1
# right and not left
# dif: -82
# -2
# right and not left
# dif: -81
# -3
# right and not left
# dif: -88
# -4
# right and not left
# dif: -93
# -5
# right and not left
# dif: -101
# -5
# right and not left
# dif: -111
# -5
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# no line
# right and not left
# dif: -110
# -1
# right and not left
# dif: -111
# -2
# right and not left
# dif: -104
# -3
# right and not left
# dif: -98
# -4
# right and not left
# dif: -90
# -5
# right and not left
# dif: -85
# -5
# right and not left
# dif: -88
# -5
# right and not left
# dif: -79
# -5
# right and not left
# dif: -52
# -5
# right and not left
# dif: -10
# -5
# right and not left
# dif: 2
# -5
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/.local/lib/python3.7/site-packages/picamera/camera.py in capture_continuous(self, output, format, use_video_port, resize, splitter_port, burst, bayer, **options)
#    1701                         encoder.start(output)
# -> 1702                         if not encoder.wait(self.CAPTURE_TIMEOUT):
#    1703                             raise PiCameraRuntimeError(
#
# ~/.local/lib/python3.7/site-packages/picamera/encoders.py in wait(self, timeout)
#     392         """
# --> 393         result = self.event.wait(timeout)
#     394         if result:
#
# /usr/lib/python3.7/threading.py in wait(self, timeout)
#     551             if not signaled:
# --> 552                 signaled = self._cond.wait(timeout)
#     553             return signaled
#
# /usr/lib/python3.7/threading.py in wait(self, timeout)
#     299                 if timeout > 0:
# --> 300                     gotit = waiter.acquire(True, timeout)
#     301                 else:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# PiCameraValueError                        Traceback (most recent call last)
# <ipython-input-26-ecafc6a0cad9> in <module>
#      42 COUNT_VAL = 3 #3 #6
#      43
# ---> 44 for f in stream:
#      45     if first_frame:
#      46         first_frame = False
#
# ~/.local/lib/python3.7/site-packages/picamera/camera.py in capture_continuous(self, output, format, use_video_port, resize, splitter_port, burst, bayer, **options)
#    1708                     camera_port.params[mmal.MMAL_PARAMETER_CAMERA_BURST_CAPTURE] = False
#    1709         finally:
# -> 1710             encoder.close()
#    1711             with self._encoders_lock:
#    1712                 if use_video_port:
#
# ~/.local/lib/python3.7/site-packages/picamera/encoders.py in close(self)
#     429         attributes.
#     430         """
# --> 431         self.stop()
#     432         if self.encoder:
#     433             self.encoder.disconnect()
#
# ~/.local/lib/python3.7/site-packages/picamera/encoders.py in stop(self)
#     417             self.output_port.disable()
#     418         self.event.set()
# --> 419         self._close_output()
#     420
#     421     def close(self):
#
# ~/.local/lib/python3.7/site-packages/picamera/encoders.py in _close_output(self, key)
#     347                 pass
#     348             else:
# --> 349                 mo.close_stream(output, opened)
#     350
#     351     @property
#
# ~/.local/lib/python3.7/site-packages/picamera/mmalobj.py in close_stream(stream, opened)
#     369     else:
#     370         try:
# --> 371             stream.flush()
#     372         except AttributeError:
#     373             pass
#
# ~/.local/lib/python3.7/site-packages/picamera/array.py in flush(self)
#     294     def flush(self):
#     295         super(PiYUVArray, self).flush()
# --> 296         self.array = bytes_to_yuv(self.getvalue(), self.size or self.camera.resolution)
#     297         self._rgb = None
#     298
#
# ~/.local/lib/python3.7/site-packages/picamera/array.py in bytes_to_yuv(data, resolution)
#      91     if len(data) != (y_len + 2 * uv_len):
#      92         raise PiCameraValueError(
# ---> 93             'Incorrect buffer length for resolution %dx%d' % (width, height))
#      94     # Separate out the Y, U, and V values from the array
#      95     a = np.frombuffer(data, dtype=np.uint8)
#
# PiCameraValueError: Incorrect buffer length for resolution 640x480

# %%
# Release resources
stream.close()
rawCapture.close()
camera.close()
motor.duty_cycle = MOTOR_BRAKE

# %%
plt.imshow(I)
print(peaks)
# Out:
# [525]

# %%
peaks = p[0]

line_left   = None
line_right  = None
peaks_left  = peaks[peaks < CAMERA_CENTER]
peaks_right = peaks[peaks > CAMERA_CENTER]

if peaks_left.size:
    line_left = peaks_left.max()
    
if peaks_right.size:
    line_right = peaks_right.min()
    
p
# Out:
# (array([], dtype=int32), {'peak_heights': array([], dtype=float64)})

# %%
L = I[200, :]
b, a = butter(3, 0.1)
Lf = filtfilt(b, a, L)

plt.plot(L)
plt.plot(Lf)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-19-5a5d97fbd462> in <module>
# ----> 1 L = I[200, :]
#       2 b, a = butter(3, 0.1)
#       3 Lf = filtfilt(b, a, L)
#       4
#       5 plt.plot(L)
#
# IndexError: index 200 is out of bounds for axis 0 with size 180

# %%
plt.imshow(np.vstack(history))
